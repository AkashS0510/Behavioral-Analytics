# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('finalmockdata.csv')
df
# Out:
#     Unnamed: 0                 Time   Unix Time   Trans_Id Name      Acc Num  \
# 0            0  2024-01-05 08:15:00  1641383700  TID123459  Bob  23456789012
# 1            1  2024-01-05 12:30:00  1641401400  TID123463  Bob  23456789012
# 2            2  2024-01-05 15:45:00  1641411900  TID123512  Bob  23456789012
# 3            3  2024-01-05 19:00:00  1641422400  TID123476  Bob  23456789012
# 4            4  2024-01-05 22:15:00  1641432900  TID123456  Bob  23456789012
# ..         ...                  ...         ...        ...  ...          ...
# 92          92  2024-01-15 08:45:00  1642196700  TID123468  Bob  23456789012
# 93          93  2024-01-15 13:00:00  1642214400  TID123466  Bob  23456789012
# 94          94  2024-01-15 16:15:00  1642224900  TID123473  Bob  23456789012
# 95          95  2024-01-15 19:30:00  1642235400  TID123530  Bob  23456789012
# 96          96  2024-01-15 22:45:00  1642245900  TID123549  Bob  23456789012
#
# ...

# %%
import pickle
with open('.\\models\\amount_clusters.pkl') as amount_model:
    model_cluster= pickle.load(amount_model)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 import pickle
#       2 with open(r'.\models\amount_clusters.pkl') as amount_model:
# ----> 3     model_cluster= pickle.load(amount_model)
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
